# %% [markdown]
# # Workflow of Semantic Structure from Motion
# ## overview
# 1. Organize data
# 2. Estimate memory usage
# 3. Create 2D segmentation using SAM
# 4. Create projection associations
# 5. Run object registration

# %% [markdown]
# ## 1. Organize data
# Create a folder under `semantic_SfM/data` and organize your data following the structures below
#
# WebODM:
# ```
# semantic_SfM/data
#     ├── box_canyon_park
#         ├── DJI_photos
#         │       ├── DJI_0000.JPG
#         │       ├── DJI_0001.JPG
#         │       ├── ...
#         │       └── DJI_0100.JPG
#         ├── SfM_products
#         │       ├── camera.json
#         │       ├── shots.geojson
#         │       └── model.las
#         ├── segmentations
#         └── associations
#
# ```
#
# Agisoft:
# ```
# semantic_SfM/data
#     ├── box_canyon_park
#         ├── DJI_photos
#         │       ├── DJI_0000.JPG
#         │       ├── DJI_0001.JPG
#         │       ├── ...
#         │       └── DJI_0100.JPG
#         ├── SfM_products
#         │       ├── camera_para.xml
#         │       └── model.las
#         ├── segmentations
#         └── associations
# ```

# %% [markdown]
# ## 2. Estimate memory usage

# %%
from ssfm.memory_calculator import memory_calculator

# %%
# pointcloud file
las_file = "../../data/box_canyon_park/SfM_products/model.las"
# image file sample
image_file = "../../data/box_canyon_park/DJI_photos/DJI_0183.JPG"
# number of images
num_images = 129
# number of segmentation ids for each point in the point cloud
num_segmentation_ids = 5

memory_calculator(las_file, image_file, num_images, num_segmentation_ids)

# %% [markdown]
# ## 3. Create 2D Segmentation using SAM

# %%
from ssfm.image_segmentation import ImageSegmentation
import os

# %%
sam_params = {}
sam_params['model_name'] = 'sam'
sam_params['model_path'] = '../sam/sam_vit_h_4b8939.pth'
sam_params['model_type'] = 'vit_h'
sam_params['device'] = 'cuda:1'
sam_params['points_per_side'] = 64
sam_params['pred_iou_thresh'] = 0.96
sam_params['stability_score_thresh'] = 0.92

# %%
image_segmentor = ImageSegmentation(sam_params)   
image_folder_path = '../../data/box_canyon_park/DJI_photos'
segmentation_folder_path = '../../data/box_canyon_park/segmentations'
image_paths = [os.path.join(image_folder_path, f) for f in os.listdir(image_folder_path) if f.endswith('.JPG')]
image_segmentor.batch_predict(image_paths, segmentation_folder_path, maximum_size=1000, save_overlap=True)

# %% [markdown]
# ## 4. Create projection associations

# %%
from ssfm.probabilistic_projection import *
import time

# %%
pointcloud_projector = PointcloudProjection()
pointcloud_projector.read_pointcloud('../../data/box_canyon_park/SfM_products/model.las')
pointcloud_projector.read_camera_parameters('../../data/box_canyon_park/SfM_products/camera.json', '../../data/box_canyon_park/SfM_products/shots.geojson')

# batch project
image_folder_path = '../../data/box_canyon_park/DJI_photos'
save_folder_path = '../../data/box_canyon_park/associations'

image_list = [f for f in os.listdir(image_folder_path) if f.endswith('.JPG')]
pointcloud_projector.parallel_batch_project(image_list, save_folder_path)
# Out:
# Processing: DJI_0333.JPG
# Processing: DJI_0348.JPG
# Task 100/129 completed
# Time for projection:  4.68732476234436
# Processing: DJI_0366.JPG
# Task 101/129 completed
# Time for projection:  4.662702322006226
# Processing: DJI_0361.JPG
# Time for projection:  4.148681879043579
# Task 102/129 completed
# Processing: DJI_0294.JPG
# Task 103/129 completed
# Time for projection:  4.68955135345459
# Processing: DJI_0245.JPG
# Task 104/129 completed
# Time for projection:  4.673433780670166
# Processing: DJI_0183.JPG
# Time for projection:  4.159144163131714
# Task 105/129 completed
# Processing: DJI_0354.JPG
# Time for projection:  4.197078704833984
# Task 106/129 completed
# Processing: DJI_0270.JPG
# Time for projection:  4.205747604370117
# Task 107/129 completed
# Processing: DJI_0328.JPG
# Time for projection:  3.995246648788452
# Task 108/129 completed
# Processing: DJI_0277.JPG
# Time for projection:  4.178408622741699
# Task 109/129 completed
# Processing: DJI_0353.JPG
# Task 110/129 completed
# Time for projection:  4.811924457550049
# Processing: DJI_0279.JPG
# Task 111/129 completed
# Time for projection:  4.501382350921631
# Processing: DJI_0321.JPG
# Task 112/129 completed
# Time for projection:  4.996877193450928
# Processing: DJI_0326.JPG
# Task 113/129 completed
# Time for projection:  5.237075090408325
# Processing: DJI_0337.JPG
# Time for projection:  4.056168079376221
# Task 114/129 completed
# Processing: DJI_0330.JPG
# Task 115/129 completed
# Time for projection:  4.642173528671265
# Processing: DJI_0268.JPG
# Task 116/129 completed
# Time for projection:  4.960785388946533
# Processing: DJI_0266.JPG
# Time for projection:  4.12667179107666
# Task 117/129 completed
# Processing: DJI_0342.JPG
# Task 118/129 completed
# Time for projection:  4.284378290176392
# Processing: DJI_0345.JPG
# Time for projection:  3.7709667682647705
# Task 119/129 completed
# Processing: DJI_0339.JPG
# Task 120/129 completed
# Time for projection:  4.763113975524902
# Processing: DJI_0261.JPG
# Time for projection:  4.126749515533447
# Task 121/129 completed
# Processing: DJI_0254.JPG
# Task 122/129 completed
# Time for projection:  4.806333780288696
# Processing: DJI_0285.JPG
# Task 123/129 completed
# Time for projection:  4.92981743812561
# Processing: DJI_0253.JPG
# Task 124/129 completed
# Time for projection:  4.603595018386841
# Processing: DJI_0282.JPG
# Task 125/129 completed
# Time for projection:  5.19287109375
# Processing: DJI_0305.JPG
# Task 126/129 completed
# Time for projection:  5.158435344696045
# Processing: DJI_0302.JPG
# Task 127/129 completed
# Time for projection:  5.4810709953308105
# Task 128/129 completed
# Time for projection:  4.941025972366333
# Task 129/129 completed
# Executor shut down.

# %%
# build keyimage associations
t1 = time.time()
pointcloud_projector.build_associations_keyimage('../../data/box_canyon_park/associations', '../../data/box_canyon_park/segmentations')
t2 = time.time()
print('Time for building keyimage associations: ', t2 - t1)
# Out:
# Time for building keyimage associations:  102.73334264755249

# %% [markdown]
# ## 5. Run object registration

# %%
from ssfm.object_registration import *
import logging

# %%
# Set paths
pointcloud_path = '../../data/box_canyon_park/SfM_products/model.las'
segmentation_folder_path = '../../data/box_canyon_park/segmentations'
image_folder_path = '../../data/box_canyon_park/DJI_photos'
association_folder_path = '../../data/box_canyon_park/associations'


# Create object registration
t1 = time.time()
obr = ObjectRegistration(pointcloud_path, segmentation_folder_path, association_folder_path)
t2 = time.time()
print('Time elapsed for creating object registration: {}'.format(t2-t1))

# Run object registration
obr.object_registration(iou_threshold=0.5)

# save semantic point cloud
obr.save_semantic_pointcloud('../../data/box_canyon_park/semantic_model.las')
# Out:
# Time elapsed for creating object registration: 2.9036059379577637
# Processing image 1/129: DJI_0183.npy
# Processing image 2/129: DJI_0184.npy
# Processing image 3/129: DJI_0241.npy
# Processing image 4/129: DJI_0242.npy
# Processing image 5/129: DJI_0243.npy
# Processing image 6/129: DJI_0244.npy
# Processing image 7/129: DJI_0245.npy
# Processing image 8/129: DJI_0246.npy
# Processing image 9/129: DJI_0247.npy
# Processing image 10/129: DJI_0248.npy
# Processing image 11/129: DJI_0249.npy
# Processing image 12/129: DJI_0250.npy
# Processing image 13/129: DJI_0251.npy
# Processing image 14/129: DJI_0252.npy
# Processing image 15/129: DJI_0253.npy
# Processing image 16/129: DJI_0254.npy
# Processing image 17/129: DJI_0255.npy
# Processing image 18/129: DJI_0256.npy
# Processing image 19/129: DJI_0257.npy
# Processing image 20/129: DJI_0258.npy
# Processing image 21/129: DJI_0259.npy
# Processing image 22/129: DJI_0260.npy
# Processing image 23/129: DJI_0261.npy
# Processing image 24/129: DJI_0262.npy
# Processing image 25/129: DJI_0263.npy
# Processing image 26/129: DJI_0264.npy
# Processing image 27/129: DJI_0265.npy
# Processing image 28/129: DJI_0266.npy
# Processing image 29/129: DJI_0267.npy
# Processing image 30/129: DJI_0268.npy
# Processing image 31/129: DJI_0269.npy
# Processing image 32/129: DJI_0270.npy
# Processing image 33/129: DJI_0271.npy
# Processing image 34/129: DJI_0272.npy
# Processing image 35/129: DJI_0273.npy
# Processing image 36/129: DJI_0274.npy
# Processing image 37/129: DJI_0275.npy
# Processing image 38/129: DJI_0276.npy
# Processing image 39/129: DJI_0277.npy
# Processing image 40/129: DJI_0278.npy
# Processing image 41/129: DJI_0279.npy
# Processing image 42/129: DJI_0280.npy
# Processing image 43/129: DJI_0281.npy
# Processing image 44/129: DJI_0282.npy
# Processing image 45/129: DJI_0283.npy
# Processing image 46/129: DJI_0284.npy
# Processing image 47/129: DJI_0285.npy
# Processing image 48/129: DJI_0286.npy
# Processing image 49/129: DJI_0287.npy
# Processing image 50/129: DJI_0288.npy
# Processing image 51/129: DJI_0289.npy
# Processing image 52/129: DJI_0290.npy
# Processing image 53/129: DJI_0291.npy
# Processing image 54/129: DJI_0292.npy
# Processing image 55/129: DJI_0293.npy
# Processing image 56/129: DJI_0294.npy
# Processing image 57/129: DJI_0295.npy
# Processing image 58/129: DJI_0296.npy
# Processing image 59/129: DJI_0297.npy
# Processing image 60/129: DJI_0298.npy
# Processing image 61/129: DJI_0299.npy
# Processing image 62/129: DJI_0302.npy
# Processing image 63/129: DJI_0303.npy
# Processing image 64/129: DJI_0304.npy
# Processing image 65/129: DJI_0305.npy
# Processing image 66/129: DJI_0306.npy
# Processing image 67/129: DJI_0307.npy
# Processing image 68/129: DJI_0308.npy
# Processing image 69/129: DJI_0309.npy
# Processing image 70/129: DJI_0310.npy
# Processing image 71/129: DJI_0311.npy
# Processing image 72/129: DJI_0312.npy
# Processing image 73/129: DJI_0313.npy
# Processing image 74/129: DJI_0314.npy
# Processing image 75/129: DJI_0315.npy
# Processing image 76/129: DJI_0316.npy
# Processing image 77/129: DJI_0317.npy
# Processing image 78/129: DJI_0318.npy
# Processing image 79/129: DJI_0319.npy
# Processing image 80/129: DJI_0320.npy
# Processing image 81/129: DJI_0321.npy
# Processing image 82/129: DJI_0322.npy
# Processing image 83/129: DJI_0323.npy
# Processing image 84/129: DJI_0324.npy
# Processing image 85/129: DJI_0325.npy
# Processing image 86/129: DJI_0326.npy
# Processing image 87/129: DJI_0327.npy
# Processing image 88/129: DJI_0328.npy
# Processing image 89/129: DJI_0329.npy
# Processing image 90/129: DJI_0330.npy
# Processing image 91/129: DJI_0331.npy
# Processing image 92/129: DJI_0332.npy
# Processing image 93/129: DJI_0333.npy
# Processing image 94/129: DJI_0334.npy
# Processing image 95/129: DJI_0335.npy
# Processing image 96/129: DJI_0336.npy
# Processing image 97/129: DJI_0337.npy
# Processing image 98/129: DJI_0338.npy
# Processing image 99/129: DJI_0339.npy
# Processing image 100/129: DJI_0340.npy
# Processing image 101/129: DJI_0341.npy
# Processing image 102/129: DJI_0342.npy
# Processing image 103/129: DJI_0343.npy
# Processing image 104/129: DJI_0344.npy
# Processing image 105/129: DJI_0345.npy
# Processing image 106/129: DJI_0346.npy
# Processing image 107/129: DJI_0347.npy
# Processing image 108/129: DJI_0348.npy
# Processing image 109/129: DJI_0349.npy
# Processing image 110/129: DJI_0350.npy
# Processing image 111/129: DJI_0351.npy
# Processing image 112/129: DJI_0352.npy
# Processing image 113/129: DJI_0353.npy
# Processing image 114/129: DJI_0354.npy
# Processing image 115/129: DJI_0355.npy
# Processing image 116/129: DJI_0356.npy
# Processing image 117/129: DJI_0357.npy
# Processing image 118/129: DJI_0358.npy
# Processing image 119/129: DJI_0359.npy
# Processing image 120/129: DJI_0360.npy
# Processing image 121/129: DJI_0361.npy
# Processing image 122/129: DJI_0362.npy
# Processing image 123/129: DJI_0363.npy
# Processing image 124/129: DJI_0364.npy
# Processing image 125/129: DJI_0365.npy
# Processing image 126/129: DJI_0366.npy
# Processing image 127/129: DJI_0367.npy
# Processing image 128/129: DJI_0368.npy
# Processing image 129/129: DJI_0369.npy
